# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import eig
from scipy.io import loadmat

if __name__=='__main__':
    data = loadmat('teapots.mat')
    X = data['teapotImages']
    u = np.mean(X, axis=0).reshape(1,1900)
    x = X - np.repeat(u,100,axis=0)
    images = plt.imsave('image.png', x , format='PNG')
    C = x.T.dot(x)/(x.shape[0]-1)
    D, V = eig(C)
    print(x.shape)
    print(C)
    #print(D[:3])
    #print(V[:,:3])
# Out:
# (100, 1900)
# [[ 4.83281273e-06  2.96872782e-06  2.89968764e-06 ... -2.55448673e-05
#   -1.13571099e-05  1.61899226e-05]
#  [ 2.96872782e-06  5.08549979e-06  3.84760933e-06 ... -1.07557699e-05
#   -3.50544619e-05  2.13458434e-05]
#  [ 2.89968764e-06  3.84760933e-06  6.29577418e-06 ... -2.89620111e-05
#   -5.15536846e-05  2.46069564e-05]
#  ...
#  [-2.55448673e-05 -1.07557699e-05 -2.89620111e-05 ...  7.36547913e-03
#    2.94650102e-03 -7.10929190e-05]
#  [-1.13571099e-05 -3.50544619e-05 -5.15536846e-05 ...  2.94650102e-03
#    7.30979218e-03 -3.52140828e-04]
#  [ 1.61899226e-05  2.13458434e-05  2.46069564e-05 ... -7.10929190e-05
#   -3.52140828e-04  3.69560184e-04]]

# %%
import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import eig
from scipy.io import loadmat

Data = loadmat('teapots.mat')
X = Data['teapotImages']
X = np.expand_dims(X, axis=0)
imgplot = plt.imshow(X[0,:])
